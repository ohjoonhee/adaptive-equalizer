# %%
import sys

sys.path.append("../src")

import torch
from dataset.noise import NoiseDataset

# %%
ds = NoiseDataset(
    "../data/noise_samples_132300_length_44100_hz.npz", sample_length=44100 * 5
)
e = next(iter(ds))
print(e.shape)
# Out:
# torch.Size([1, 132300])

# %%
import IPython.display as ipd

ipd.Audio(e, rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
